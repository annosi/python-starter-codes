# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('data/parsed.csv')
df.sample(5)
# Out:
#      alert  cdi      code                                             detail  \
# 2750   NaN  NaN  20270868  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 6154   NaN  2.0  73089931  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3159   NaN  NaN  20270179  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5219   NaN  NaN  20273732  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 6973   NaN  NaN  73089066  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#          dmin  felt   gap                      ids   mag magType  ...  \
# 2750      NaN   NaN   NaN             ,ak20270868,  1.40      ml  ...
# 6154  0.13500   1.0  82.0  ,nc73089931,nn00658221,  2.46      md  ...
# 3159      NaN   NaN   NaN             ,ak20270179,  1.00      ml  ...
# 5219      NaN   NaN   NaN             ,ak20273732,  0.90      ml  ...
# 6973  0.01067   NaN  50.0             ,nc73089066,  1.60      md  ...
#
#         status           time                                title tsunami  \
# ...

# %% [markdown]
# **Find the 95th percentile of earthquake magnitude in Japan using the mb
# magnitude type.**

# %%
df[(df.parsed_place=='Japan')&(df.magType=='mb')].describe(percentiles=[0.95]).at['95%','mag']
# Out:
# 4.9

# %%
#above method is too long.
#use the python code for percentiles which is quantile
df[(df.parsed_place=='Japan')&(df.magType=='mb')]['mag'].quantile(0.95)
# Out:
# 4.9

# %% [markdown]
# **Find the percentage of earthquakes in Indonesia that were coupled with tsunamis.**

# %%
all_earthquake = df[df.parsed_place=='Indonesia']['type'].count()
print(all_earthquake)
with_tsunami = df[(df.parsed_place=='Indonesia') & (df.tsunami==1)]['type'].count()
print(with_tsunami)
print(100*with_tsunami/all_earthquake,'%')
# Out:
# 147
# 34
# 23.12925170068027 %

# %% [markdown]
# **Calculate summary statistics for earthquakes in Nevada.**

# %%
df[(df.parsed_place=='Nevada')].describe()
# Out:
#              cdi        dmin       felt         gap         mag   mmi  \
# count  15.000000  681.000000  15.000000  681.000000  681.000000  1.00
# mean    2.440000    0.166199   2.400000  153.668120    0.500073  2.84
# std     0.501142    0.166228   4.626013   68.735302    0.696710   NaN
# min     2.000000    0.001000   1.000000   29.140000   -0.500000  2.84
# 25%     2.000000    0.053000   1.000000   97.380000   -0.100000  2.84
# 50%     2.200000    0.112000   1.000000  149.140000    0.400000  2.84
# 75%     2.900000    0.233000   1.000000  199.720000    0.900000  2.84
# max     3.300000    1.414000  19.000000  355.910000    2.900000  2.84
#
#               nst         rms         sig          time  tsunami     tz  \
# count  681.000000  681.000000  681.000000  6.810000e+02    681.0  681.0
# mean    12.618209    0.151986   10.970631  1.538314e+12      0.0 -480.0
# std      9.866963    0.084662   19.607150  5.965637e+08      0.0    0.0
# ...

# %% [markdown]
# **Add a column indicating whether the earthquake happened in a country or US
# state that is on the Ring of Fire. Use Alaska, Antarctica (look for Antarctic), Bolivia,
# California, Canada, Chile, Costa Rica, Ecuador, Fiji, Guatemala, Indonesia, Japan,
# Kermadec Islands, Mexico (be careful not to select New Mexico), New Zealand,
# Peru, Philippines, Russia, Taiwan, Tonga, and Washington.**

# %%
df['Ring of Fire'] = (
    (df.parsed_place=='Alaska')|(df.parsed_place=='Antarctic')|(df.parsed_place=='Bolivia')|(df.parsed_place=='California')|
    (df.parsed_place=='Canada')|(df.parsed_place=='Chile')|(df.parsed_place=='Costa Rica')|(df.parsed_place=='Ecuador')|
    (df.parsed_place=='Fiji')|(df.parsed_place=='Guatemala')|(df.parsed_place=='Indonesia')|(df.parsed_place=='Japan')|
    (df.parsed_place=='Kermadec Islands')|(df.parsed_place=='Mexico')|(df.parsed_place=='New Zealand')|
    (df.parsed_place=='Peru')|(df.parsed_place=='Philippines')|(df.parsed_place=='Russia')|(df.parsed_place=='Taiwan')|
    (df.parsed_place=='Tonga')|(df.parsed_place=='Washington')
)
df.head(10)
# Out:
#   alert  cdi        code                                             detail  \
# 0   NaN  NaN    37389218  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 1   NaN  NaN    37389202  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 2   NaN  4.4    37389194  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 3   NaN  NaN    37389186  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 4   NaN  NaN    73096941  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 5   NaN  NaN  2018286011  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 6   NaN  NaN    20280432  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 7   NaN  NaN    73096936  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 8   NaN  NaN    73096931  https://earthquake.usgs.gov/fdsnws/event/1/que...
# 9   NaN  NaN    1000hbtn  https://earthquake.usgs.gov/fdsnws/event/1/que...
#
#        dmin  felt    gap             ids   mag magType  ...           time  \
# ...

# %% [markdown]
# **Calculate the number of earthquakes in the Ring of Fire locations and the number
# outside of them.**

# %%
in_location = df[df['Ring of Fire']==True]['type'].count()
print(in_location)
out_location = df[df['Ring of Fire']==False]['type'].count()
print(out_location)
#do the below simply since you know it contains only true and false
test = df['Ring of Fire'].value_counts()
print(test)
# Out:
# 7184
# 2148
# True     7184
# False    2148
# Name: Ring of Fire, dtype: int64

# %% [markdown]
# **Find the tsunami count along the Ring of Fire.**

# %%
tsunami_count = df[df['Ring of Fire']==True]['tsunami'].sum()
print(tsunami_count)
# Out:
# 45

# %%
#OR
tsunami_count2 = df[(df['Ring of Fire']==True) & (df.tsunami==1)]['tsunami'].count()
print(tsunami_count2)
# Out:
# 45

# %%
#best solution simple and short
df.loc[df['Ring of Fire'], 'tsunami'].sum()
# Out:
# 45

# %%
df['Ring of Fire'].value_counts

# %%
df.['Ring of Fire'].value_counts

# %%
df.['Ring of Fire']value_counts
